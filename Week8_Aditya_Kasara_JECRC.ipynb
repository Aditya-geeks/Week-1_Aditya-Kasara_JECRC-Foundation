# %%
import json
import logging
import re
import sys
from typing import Dict, Any

# 🪵 Colab Logging Setup (Prevents duplicate outputs in Colab cells)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
if not logger.handlers:
    handler = logging.StreamHandler(sys.stdout)
    handler.setFormatter(logging.Formatter('%(levelname)s: %(message)s'))
    logger.addHandler(handler)

# %%
def calculator(expression: str) -> str:
    """Evaluate a mathematical expression safely."""
    try:
        # Sanitize input: allow only digits, operators, dots, and brackets
        sanitized = re.sub(r'[^0-9+\-*/().\s]', '', expression)
        if not sanitized.strip():
            return "Error in calculation"
        return str(eval(sanitized))
    except Exception:
        return "Error in calculation"

def extract_keywords(text: str) -> list:
    """Extract keywords from text."""
    try:
        # Strip simple punctuation symbols for clean word tokenization
        clean_text = re.sub(r'[^\w\s]', '', text)
        words = clean_text.split()
        keywords = list(set([w.lower() for w in words if len(w) > 4]))
        return keywords[:5]
    except Exception:
        return []

def text_stats(text: str) -> dict:
    """🚀 BONUS TOOL: Evaluates basic string metrics."""
    try:
        words = text.split()
        return {
            "word_count": len(words),
            "char_count": len(text),
            "uppercase_count": sum(1 for w in words if w.isupper() and len(w) > 1)
        }
    except Exception:
        return {}

# %%
print("="*60)
print("🚀 RUNNING AGENT PIPELINE SIMULATION")
print("="*60)

test_queries = [
    "Calculate 20 + 5 * 2",
    "Extract keywords from Artificial Intelligence is transforming engineering industries",
    "Analyze this specific string configuration right now.",
    "What is machine learning?"
]

for q in test_queries:
    print(f"\nQuery: {q}")
    response = agent(q)
    print(f"Structured Response:\n{json.dumps(response, indent=2)}")
    print("-" * 50)
# Out:
# INFO:root:Routing to Calculator -> Expression: 'Calculate 20 + 5 * 2'
# INFO:root:Routing to Keyword Extractor -> Text snippet: 'Artificial Intelligence is tra...'
# INFO:root:Routing to Text Stats -> Text snippet: 'this specific string configura...'
# INFO:root:Routing to General Intent Pipeline
# ============================================================
# 🚀 RUNNING AGENT PIPELINE SIMULATION
# ============================================================
#
# Query: Calculate 20 + 5 * 2
# Structured Response:
# {
#   "type": "calculation",
#   "result": 30
# }
# --------------------------------------------------
#
# Query: Extract keywords from Artificial Intelligence is transforming engineering industries
# Structured Response:
# {
#   "type": "keywords",
#   "result": [
#     "industries",
#     "intelligence",
#     "engineering",
#     "transforming",
#     "artificial"
#   ]
# }
# --------------------------------------------------
#
# Query: Analyze this specific string configuration right now.
# Structured Response:
# {
#   "type": "text_analysis",
#   "result": {
#     "word_count": 6,
#     "char_count": 45,
#     "uppercase_count": 0
#   }
# }
# --------------------------------------------------
#
# Query: What is machine learning?
# Structured Response:
# {
#   "type": "general",
#   "result": "Direct Response: I processed your query without structural tools: 'What is machine learning?'"
# }
# --------------------------------------------------

# %%
print("\n" + "="*60)
print("🎯 INTERACTIVE PLAYGROUND ACTIVE")
print("="*60)
print("Type your prompts below. Type 'exit' to stop the playground.\n")

while True:
    user_input = input("Enter query: ")
    if user_input.lower() == "exit":
        print("Playground closed.")
        break

    response = agent(user_input)
    print(f"Response:\n{json.dumps(response, indent=2)}")
    print("-" * 40)
# Out:
# ============================================================
# 🎯 INTERACTIVE PLAYGROUND ACTIVE
# ============================================================
# Type your prompts below. Type 'exit' to stop the playground.
#
# Enter query: Celebal Tech provides Data, AI, Cloud, and IT consulting services tailored to industry needs, helping enterprises adopt digital and analytics solutions.
# INFO:root:Routing to General Intent Pipeline
# Response:
# {
#   "type": "general",
#   "result": "Direct Response: I processed your query without structural tools: 'Celebal Tech provides Data, AI, Cloud, and IT consulting services tailored to industry needs, helping enterprises adopt digital and analytics solutions.'"
# }
# ----------------------------------------
# Enter query: calculate 99 * 99
# INFO:root:Routing to Calculator -> Expression: '99 * 99'
# Response:
# {
#   "type": "calculation",
#   "result": 9801
# }
# ----------------------------------------
# Enter query: Extract keywords from the data analytics framework
# INFO:root:Routing to Keyword Extractor -> Text snippet: 'the data analytics framework...'
# Response:
# {
#   "type": "keywords",
#   "result": [
#     "framework",
#     "analytics"
#   ]
# }
# ----------------------------------------
# Enter query: Can you analyze this short text string?
# INFO:root:Routing to Text Stats -> Text snippet: 'this short text string?...'
# Response:
# {
#   "type": "text_analysis",
#   "result": {
#     "word_count": 4,
#     "char_count": 23,
#     "uppercase_count": 0
#   }
# }
# ----------------------------------------
# Enter query: exit
# Playground closed.
